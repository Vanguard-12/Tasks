# %% [markdown]
# # DeepAgent Demo Notebook
#
# This notebook demonstrates the same workflow as the command‑line script
# `agent.py`. It runs the interactive loop programmatically so you can see the
# intermediate virtual files without leaving the notebook environment.

# %%
from agent import run_interactive

# %%
# Execute the interactive function. In the notebook you can provide the
# query directly in the input prompt that appears.

# %%
run_interactive()
